# %% [markdown]
# # Linear Regression

# %% [markdown]
# Assignment about peoples Height and Weight

# %%
import pandas as pd  # import library 
import matplotlib.pyplot as plt

# %%
import warnings as wr  # import warnings module for ignore warning
wr.filterwarnings("ignore")

# %%
df = pd.read_csv("Height-Weight Data.csv") # read the csv file

# %%
df.head() # it shows 5 rows
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
df.shape # it shows how many row and column we have.
# Out:
# (3501, 2)

# %%
df.isnull().sum() # it shows how many missing values we have.
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.info() # as like as isnull().sum() but it shows in details.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3501 entries, 0 to 3500
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  3501 non-null   float64
#  1   Weight  3501 non-null   float64
# dtypes: float64(2)
# memory usage: 54.8 KB

# %%
df.columns
# Out:
# Index(['Height', 'Weight'], dtype='object')

# %%
plt.scatter(df.Height,df.Weight,color="Green")# it shows all ponts of dataset
plt.xlabel("Height in C.M.") # anything you can write, it willbe showing for X-axis
plt.ylabel("Weight in POUND") # anything you can write , it willbe showing for Y-axis
plt.title("Height-Weight plot") # for caption or title
# Out:
# Text(0.5, 1.0, 'Height-Weight plot')

# %%
df.Height.mean() # X-mean
# Out:
# 69.02441087268797

# %%
df.Weight.mean() # Y-mean
# Out:
# 186.89125797946284

# %%
x = df[["Height"]] #Height assigned to independent variable x

# %%
y= df[["Weight"]]  #Weight assignment to dependent variable y

# %%
x.head() # first 5  height value
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796

# %%
y.head() # first 5 weight value
# Out:
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801

# %%
from sklearn.linear_model import LinearRegression # just import Linear Regression Module from sklearn library

# %%
regg=LinearRegression() # creating object for Linear Regression

# %%
regg.fit(x,y) #training the model
# Out:
# LinearRegression()

# %%
regg.coef_ # the value of (coefficient) m in the equation of y=mx+c
# Out:
# array([[5.95843786]])

# %%
regg.intercept_ # the value of (intercept) c in the equation of y=mx+c
# Out:
# array([-224.38640537])

# %%
regg.predict([[72]]) # it shows predicted weight, when we give height
# Out:
# array([[204.62112091]])

# %%
# y = (m*x)+c
result=((regg.coef_)*72) + regg.intercept_
result # manually process
# Out:
# array([[204.62112091]])

# %%
regg.predict(x) # predict all weight from dataset
# Out:
# array([[215.62645706],
#        [185.44629614],
#        [217.19405276],
#        ...,
#        [216.01692618],
#        [177.18859679],
#        [209.02422774]])

# %%
df["predicted_Weight"]= regg.predict(x) #add a new column name "predict_Weight"

# %%
df.head()
# Out:
#       Height      Weight  predicted_Weight
# 0  73.847017  241.893563        215.626457
# 1  68.781904  162.310473        185.446296
# 2  74.110105  212.740856        217.194053
# 3  71.730978  220.042470        203.018172
# 4  69.881796  206.349801        191.999933

# %%
plt.plot(df.Height.squeeze(), regg.predict(df[["Height"]])) # it shows the predict main result's line
plt.scatter(df.Height,df.Weight,color="Green")# it shows all ponts of dataset
plt.xlabel("Height in C.M") # anything you can write, it willbe showing for X-axis
plt.ylabel("weight in POUND") # anything you can write , it willbe showing for Y-axis
plt.title("Height-weight plot") # for caption or title
# Out:
# Text(0.5, 1.0, 'Height-weight plot')

# %%
regg.score(x,y) # training accuracy
# Out:
# 0.7323584758139253

# %%
from sklearn.metrics import mean_squared_error # import MSE from sklearn

# %%
mean_squared_error(df[["Weight"]], regg.predict(df[["Height"]])) #MSE (Mean Squre Error) value
# Out:
# 105.99179779708444

# %%
mean_squared_error(y,df.predicted_Weight) # df[["Height"]] = x
# Out:
# 105.99179779708444

# %%
from sklearn.metrics import mean_absolute_error

# %%
# print MAE
mean_absolute_error(y,df.predicted_Weight)
# Out:
# 8.070234283451889
